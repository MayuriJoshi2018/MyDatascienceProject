# %% [markdown]
# ### Olympic Games are leading international sporting events in which thousands of athletes from around the world participate in a variety of competitions.
# ### The Olympic Games are considered the world’s foremost sports competition with more than 200 nations participating.
# ### The Olympic Games are normally held every four years, alternating between the Summer and Winter Olympics every two years in the four-year period. In Tokyo Olympic,around 11,656 Athlete’s took part from 205+ Countries.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
get the necessary librabries
'''
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Our Next Step is to Download Dataset from Kaggle.
# Dataset link:
# https://www.kaggle.com/berkayalan/2021-olympics-medals-in-tokyo
# After downloading the Dataset we save it into Same project folder where we are Working and import it by Using pandas in project

# %%
medaltally=pd.read_csv("C:/kaggaledataset/Olympics_2021.csv")

# %%
medaltally.shape
# Out:
# (93, 7)

# %%
medaltally.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
# Rank             93 non-null int64
# Country          93 non-null object
# Gold             93 non-null int64
# Silver           93 non-null int64
# Bronze           93 non-null int64
# Total            93 non-null int64
# Rank by Total    93 non-null int64
# dtypes: int64(6), object(1)
# memory usage: 5.2+ KB

# %%
# see the first 10 rows
medaltally.head(10)
# Out:
#    Rank                     Country  Gold  Silver  Bronze  Total  \
# 0     1    United States of America    39      41      33    113
# 1     2  People's Republic of China    38      32      18     88
# 2     3                       Japan    27      14      17     58
# 3     4               Great Britain    22      21      22     65
# 4     5                         ROC    20      28      23     71
# 5     6                   Australia    17       7      22     46
# 6     7                 Netherlands    10      12      14     36
# 7     8                      France    10      12      11     33
# 8     9                     Germany    10      11      16     37
# 9    10                       Italy    10      10      20     40
#
#    Rank by Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3
# 5              6
# 6              9
# 7             10
# 8              8
# 9              7

# %%
# see the last 10 rows
medaltally.tail(10)
# Out:
#     Rank               Country  Gold  Silver  Bronze  Total  Rank by Total
# 83    84                Mexico     0       0       4      4             47
# 84    85               Finland     0       0       2      2             66
# 85    86              Botswana     0       0       1      1             77
# 86    86          Burkina Faso     0       0       1      1             77
# 87    86         Côte d'Ivoire     0       0       1      1             77
# 88    86                 Ghana     0       0       1      1             77
# 89    86               Grenada     0       0       1      1             77
# 90    86                Kuwait     0       0       1      1             77
# 91    86   Republic of Moldova     0       0       1      1             77
# 92    86  Syrian Arab Republic     0       0       1      1             77

# %%
top_10_countries= medaltally.Country.value_counts().sort_values(ascending=False)
top_10_countries
# Out:
# United States of America    1
# Mongolia                    1
# Kenya                       1
# New Zealand                 1
# Grenada                     1
#                            ..
# Bermuda                     1
# Kosovo                      1
# Romania                     1
# Bahamas                     1
# Bahrain                     1
# Name: Country, Length: 93, dtype: int64

# %%
medaltally.describe()
# Out:
#             Rank       Gold     Silver     Bronze       Total  Rank by Total
# count  93.000000  93.000000  93.000000  93.000000   93.000000      93.000000
# mean   46.333333   3.655914   3.634409   4.322581   11.612903      43.494624
# std    26.219116   7.022471   6.626339   6.210372   19.091332      24.171769
# min     1.000000   0.000000   0.000000   0.000000    1.000000       1.000000
# 25%    24.000000   0.000000   0.000000   1.000000    2.000000      23.000000
# 50%    46.000000   1.000000   1.000000   2.000000    4.000000      47.000000
# 75%    70.000000   3.000000   4.000000   5.000000   11.000000      66.000000
# max    86.000000  39.000000  41.000000  33.000000  113.000000      77.000000

# %%
countries = medaltally["Country"]
countries.head(10)
# Out:
# 0      United States of America
# 1    People's Republic of China
# 2                         Japan
# 3                 Great Britain
# 4                           ROC
# 5                     Australia
# 6                   Netherlands
# 7                        France
# 8                       Germany
# 9                         Italy
# Name: Country, dtype: object

# %%
Total_medals =medaltally['Total']

# %%
rank_by_Total = medaltally['Rank by Total']
rank_by_Total.head(10)
# Out:
# 0     1
# 1     2
# 2     5
# 3     4
# 4     3
# 5     6
# 6     9
# 7    10
# 8     8
# 9     7
# Name: Rank by Total, dtype: int64

# %%
Gold_Medals = medaltally['Gold']

# %%
top20_rank_df=medaltally.sort_values('Rank by Total',ascending=True).head(20)
top20_rank_df
# Out:
#     Rank                     Country  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 4      5                         ROC    20      28      23     71
# 3      4               Great Britain    22      21      22     65
# 2      3                       Japan    27      14      17     58
# 5      6                   Australia    17       7      22     46
# 9     10                       Italy    10      10      20     40
# 8      9                     Germany    10      11      16     37
# 6      7                 Netherlands    10      12      14     36
# 7      8                      France    10      12      11     33
# 10    11                      Canada     7       6      11     24
# 11    12                      Brazil     7       6       8     21
# 15    16           Republic of Korea     6       4      10     20
# ...

# %% [markdown]
# # USA has topped in the list With total of 113 Medals in Tokyo Olympic.

# %%
plt.figure(figsize=(25,8))
plt.title("TOKYO OLYMPICS 2021 Top 20 contries MEDAL TALLY")
plt.xlabel("Contry Name")
plt.ylabel("Number Gold Medals earned")
plt.bar(top20_rank_df['Country'],top20_rank_df['Total'],color='orange')
#plt.pie(MedalsEarned)
plt.savefig('graph.png')
plt.show()

# %%
plt.figure(figsize=(25,8))
plt.title("TOKYO OLYMPICS 2021 last 15 contries MEDAL TALLY")
plt.xlabel("Contry Name")
plt.ylabel("Number Gold Medals earned")
sns.barplot(top20_rank_df['Country'],top20_rank_df['Total'],palette='Set2')
#plt.pie(MedalsEarned)
plt.savefig('graph.png')
plt.show()

# %%
medaltally.query('Country == "United States of America" ')
# Out:
#    Rank                   Country  Gold  Silver  Bronze  Total  Rank by Total
# 0     1  United States of America    39      41      33    113              1

# %%
medaltally.query('Country == "India" ')
# Out:
#     Rank Country  Gold  Silver  Bronze  Total  Rank by Total
# 47    48   India     1       2       4      7             33

# %%
plt.figure(figsize=(20,14))
sns.barplot(x='Country',y='Gold',data=medaltally)
plt.plot(medaltally.Country,medaltally.Gold,marker='s',c='g',ls='-',lw=3,ms=5,mew=1,mec='navy');
plt.tick_params(axis='x',which='major',labelsize=13,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=20)
plt.title("Gold Medal Won By Each Countries",fontsize=30,pad=20)
plt.xlabel("Countries",fontsize=25)
plt.ylabel("Gold Medals Won",fontsize=25)
plt.legend(['Countries',' Gold Medals Won']);
plt.grid(color='g',linestyle='-',linewidth=0.3,alpha=0.5)

# %%
bins = np.arange(0, 10, 5)
g = sns.FacetGrid(medaltally, col="Country",  row="Total")
g = g.map(plt.hist, "Country",bins=bins, color="g")

# %%
fig = plt.figure(figsize=(15,15))
sns.lmplot(x="Silver", y="Total", hue="Country", col="Gold", data=medaltally,size=10,aspect=0.2);

# %%
# Load the dataset
url = "C://kaggaledataset//athlete_events.csv"
athelets = pd.read_csv(url)

# %%
athelets.shape

# %%
# # Print the last five rows of the data set
athelets.tail()

# %%
# Print the first five rows of the data set
athelets.head()

# %%
url2 = "C:/kaggaledataset/noc_regions.csv"
regions = pd.read_csv(url2)

# %%
# see the dimension of the dataset
regions.shape

# %%
# see the first 10 rows of the region data set
regions.head(10)

# %%
# join 2 data sets
athetes_df = athelets.merge(regions,how='left',on ="NOC")
athetes_df.head(10)

# %%
athetes_df.rename(columns={'region':'Region','notes':'Notes'},inplace =True)

# %%
athetes_df.info()

# %%
athetes_df.head(10)

# %%
# Get the information of the numberical columns
athetes_df.describe()
