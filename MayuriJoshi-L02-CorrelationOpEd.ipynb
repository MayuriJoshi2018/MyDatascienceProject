# %% [markdown]
# ## My take on the following article
# ### URL:https://www.inman.com/2018/04/09/spring-forward-ira-serkes-stop-searching-for-balance-strive-for-harmony/
# ## Summary
#
# This article is written by Ira Serke, a property agent from Berkley California. The article discusses effective techniques used by Ira Serke and his team that helped them win maximum listings and in turn generated sale proceeds. The article also covers daily habits of an effective property agent.
# Ira Serkey, started his journey by shifting his focus from the amount of property sales (from being in top 5% of property agents by transactions in the Berkley area) to a happier life by having more than enough business. The change is summarized as real estate is our life to real estate funds our life.
# ## Opinion
# 1. The article describes the techniques of driving referrals and listings by Ira Serke and his team which, is very interesting and practical. Author also discusses source of business in the form of referrals. The idea of an agent giving away business to another agent is new approach to real estate business.
# 2. Ira correctly describes the success of maximum listing in various techniques such as preparing a presentation for the seller to answer any question they may have before they ask them; or personal involvement of Ira in the activities conducted by the local college continue to provide the sustained involvement, introductions. Ira associated himself with a nationwide network of agents for this purpose.  Networking is achieved by investing in local products and services.
#
# 3. Client referrals are mostly driven by hosting celebrations that are popular and attract large crowds. Other technique is Agent Referrals which generates good will among the agents population and give Ira extra income in the form of the 10% referral fee they make on each such deal they pass on.
# 4. Ira successfully made maximum money by spending least amount of time. Therefore spending 3 minutes on the phone call with the seller and then forwarding the listing to the other agent seems to be a much better deal to Ira.
# ## Charts and graphs drawn:
# 1.	Sale price and Square feet size of the home along with estimated prices from other listing sites
# 2.	Median %  overbid for # of offers
# 3.	Most of times sale price is below zestimate by 2-6%
#
#
# ## Additional graphs that may help Ira Serkes:
# 1. Sales price Vs school district with high grades
# 2. Sales price Vs Commute distance
# 3. Sales price Vs Location
# 2. Number of houses sold by an agent and in price range last year
# 3. Median price for holes sold by an agent during last year – which will hint at the median price of the area
# 4. Month, price, number of bids received
#
# ## Citation used for drawing additional plots
# https://matplotlib.org/
# https://www.safaribooksonline.com/library/view/python-data-science/9781491912126/ch04.html

# %% [markdown]
# ## Some Additional Graphs created using Matplotlib

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits import mplot3d
import datetime
import matplotlib.dates as mdates
import matplotlib.cbook as cbook

# %%
priceing1 = ["500k","700k","900k","1.5M","2M"]
No_of_houses_sold= [10,15,5,1,1]

#priceing2 =["600k","800k","950k","1M","2M"]
#No_of_houses_sold2 =[20,10,8,1,0]
#plt.subplot(1,2,2)
plt.bar(priceing1,No_of_houses_sold,color='b')
#plt.bar(priceing2,No_of_houses_sold2,color='c')
plt.title('Houses sold in last year by an agent')
plt.xlabel("Hosue Prices")
plt.ylabel("Count of houses sold")
#plt.yrange(0,25)
plt.legend()
plt.show()

# %%
priceing1 = ["500k","700k","900k","1.5M","2M"]
No_of_houses_sold= [10,15,5,1,1]

priceing2 =["600k","800k","950k","1M","2M"]
No_of_houses_sold2 =[20,10,8,1,0]

plt.subplot(2,2,1)
plt.bar(priceing1,No_of_houses_sold,color='b')
#plt.bar(priceing2,No_of_houses_sold2,color='c')
plt.title('Comparison of Houses prices sold in last year by 2 agents')
plt.xlabel("Hosue Prices")
plt.ylabel("Counts of houses sold")
#plt.ylim(0,25)
plt.legend()

plt.subplot(2,2,2)
plt.bar(priceing2,No_of_houses_sold2,color='c')
#plt.title('Houses sold in last year by an agent2')
plt.xlabel("Hosue Prices")
plt.ylabel("Count of houses sold")
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Sold as Lising price', 'Above Listing price', 'Below Listing price', 'Not sold'
sizes = [30, 40, 15, 5]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
x = np.linspace(500, 800, 100000)

plt.plot(x, x, label='zEstimate')
plt.plot(x, x*0.95, label='Actual Sales price')
#plt.plot(x, x**3, label='cubic')

plt.xlabel('Zestimate prices')
plt.ylabel('Actual sales prices')

plt.title("Comparison graph of Zillow Estimates and Atcual prices of Homes")

plt.legend()

plt.show()

# %%
ax = plt.figure(figsize=(10, 8)).gca() # define axis
rng = np.random.RandomState(0)
y = ["400K","500K","600K","700K","800K","850K","900K","950K"]
x = ["4","4","5","6","7","8","9","10"]
colors = rng.rand(8)
sizes = 500 * rng.rand(8)
plt.xlabel("School grading")
plt.ylabel("Listing price of Home")
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,cmap='viridis')
plt.colorbar()  # show color scale
